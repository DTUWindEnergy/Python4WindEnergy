# %%
import sys
sys.path.append('/Users/pire/git/Python4WindEnergy')
from py4we.mann import *
from matplotlib.pylab import imshow

# %%
inputfile_name = '../py4we/test/mann/simABLupwind.inp'
inp = MannInputFile(inputfile_name)
inp.data
# Out:
# {'L1': '10240.0',
#  'L2': '1280.0',
#  'L3': '1280.0',
#  'NComp': '3',
#  'U': '8.0',
#  'fieldDim': '3',
#  'file_u': 'sim1',
#  'file_v': 'sim2',
#  'file_w': 'sim3',
#  'n1': '1024',
#  'n2': '128',
#  'n3': '128',
#  'seeds': '-6',
#  'spectrum': '0',
#  'type': 'land',
#  'z': '90',
#  'z_0': '0.05'}

# %%
turb = MannTurbFile(inputfile_name)

# %%
imshow(turb.data[1,:,:,0])
colorbar();
